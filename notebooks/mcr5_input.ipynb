# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("../src/")

# %%
from package.logger import Timed, rlog, setup
from package import storage

setup("INFO")

# %%
import os

import folium
import geopandas as gpd
import pandas as pd

from package import strtime
from package.osm import osm
from package.mcr.data import NetworkType, OSMData
from package.mcr5.h3 import (
    get_h3_cells_for_nodes,
    get_h3_cells_for_bbox,
)
from package.h3 import plot_h3_cells_on_folium
from package.mcr5.h3_osm_interaction import get_location_mappings_for_cells
from package.mcr5.mcr5 import MCR5
from package.osm.osm import add_nearest_osm_node_id
from package.mcr5.labels import read_labels_for_nodes
from package.minute_city import minute_city

from package.geometa import GeoMeta
from package.mcr.data import NetworkType
import h3
from shapely.geometry import Polygon

# %%
city_name = "berlin"
geo_meta_path = f"../data/geometa_{city_name}.pkl"
city_id = "Berlin"
stops = f"../data/cleaned_{city_name}/stops.csv"
structs = f"../data/structs_{city_name}.pkl"
bicycle_location_path = "../data/bicycle_locations/2022-11-01_09_01_00.csv"

# %%
geo_meta = GeoMeta.load(geo_meta_path)
geo_data = OSMData(
    geo_meta,
    city_id,
    additional_network_types=[NetworkType.DRIVING],
)
nodes = geo_data.osm_nodes
edges = geo_data.osm_edges
driving_nodes, _, _ = geo_data.additional_networks[NetworkType.DRIVING]
# Out:
# [18:12:08] INFO     Using existing OSM data                                                              ]8;id=956386;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py\osm.py]8;;\:]8;id=673964;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py#106\106]8;;\
#            INFO     Loading OSM network from cache (walking)                                              ]8;id=641534;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py\osm.py]8;;\:]8;id=399852;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py#69\69]8;;\
# [18:13:00] INFO     Using existing OSM data                                                              ]8;id=707039;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py\osm.py]8;;\:]8;id=516311;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py#106\106]8;;\
#            INFO     Loading OSM network from cache (driving)                                              ]8;id=723970;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py\osm.py]8;;\:]8;id=328085;file:///home/ppeter/repo/mcr-py/notebooks/../src/package/osm/osm.py#69\69]8;;\

# %%
h3_cells = get_h3_cells_for_nodes(nodes[["lat", "lon"]].to_dict("records"), 9)
driving_h3_cells = get_h3_cells_for_nodes(
    driving_nodes[["lat", "lon"]].to_dict("records"), 9
)
h3_cells = h3_cells.intersection(driving_h3_cells)

# %%
residential_area = geo_meta.residential_area

# %%
CUTOFF = 0.25


def calculate_residential_intersection_area(h3_cell):
    boundary = h3.h3_to_geo_boundary(h3_cell)
    boundary_flipped = [(lon, lat) for lat, lon in boundary]
    poly = Polygon(boundary_flipped)
    intersection = poly.intersection(geo_meta.residential_area)
    return intersection.area / poly.area


h3_cells_filtered = {
    h3_cell
    for h3_cell in h3_cells
    if calculate_residential_intersection_area(h3_cell) > CUTOFF
}

# %%
m = folium.Map(location=geo_meta.get_center_lat_lon(), zoom_start=12)
geo_meta.add_to_folium_map(m)
plot_h3_cells_on_folium(h3_cells_filtered, m, popup_callback=lambda x, y: x)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b29c7b83c9a91003c63e878fa92ac5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b29c7b83c9a91003c63e878fa92ac5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b29c7b83c9a91003c63e878fa92ac5a = L.map(
#                 &quot;map_1b29c7b83c9a91003c63e878fa92ac5a&quot;,
#                 {
#                     center: [50.9502562166093, 6.966137805809113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9f9ad61067b70684215302f73c71fe7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a9f9ad61067b70684215302f73c71fe7.addTo(map_1b29c7b83c9a91003c63e878fa92ac5a);
#
#
#
#         function geo_json_74b4e47529dd93dcf66e96c2411b34f2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_74b4e47529dd93dcf66e96c2411b34f2 = L.geoJson(null, {
#                 onEachFeature: geo_json_74b4e47529dd93dcf66e96c2411b34f2_onEachFeature,
#
#         });
#
#         function geo_json_74b4e47529dd93dcf66e96c2411b34f2_add (data) {
#             geo_json_74b4e47529dd93dcf66e96c2411b34f2
#                 .addData(data);
#         }
#             geo_json_74b4e47529dd93dcf66e96c2411b34f2_add({&quot;coordinates&quot;: [[[6.723732722026307, 51.050985635790994], [6.723273340135411, 51.05302750707459], [6.722671793206648, 51.05785650384058], [6.7225425273632275, 51.06272110647752], [6.722886767066468, 51.06757523539012], [6.723701251530774, 51.072372910194744], [6.724978265611199, 51.07706868526516], [6.72670571288459, 51.08161808021297], [6.7269800128845905, 51.082246480212966], [6.729132490464107, 51.08659019292965], [6.729727490464108, 51.08765749292965], [6.730027136508125, 51.088194927925905], [6.7301733548696, 51.088456954309116], [6.732896392044689, 51.092797729329696], [6.736049403476518, 51.09683700873906], [6.739599273389672, 51.10053236837459], [6.7435087178423245, 51.1038449962299], [6.74773667631589, 51.10674010009367], [6.7522387429696975, 51.10918727296882], [6.756967633031255, 51.11116081243431], [6.762906733031255, 51.113289112434316], [6.764177172991253, 51.11374424502744], [6.767187270144465, 51.11482274826955], [6.767354854470721, 51.11488280510084], [6.767512764294424, 51.114939383616246], [6.769260297517119, 51.1155654195346], [6.769956930411714, 51.1158149073381], [6.774705678769712, 51.11725406171234], [6.779573689311879, 51.11821544074365], [6.784513018411611, 51.11868957608825], [6.789475020046484, 51.11867179812441], [6.794410824898834, 51.118162281942126], [6.798793646636689, 51.11726404513341], [6.798828302659302, 51.117287195064115], [6.799985591066138, 51.11790604464737], [6.8019337667468935, 51.11907489367026], [6.806112741164335, 51.12108146991542], [6.8104595938994015, 51.122692384782475], [6.81065887076239, 51.12274585650043], [6.812220862147999, 51.12372200847414], [6.81477503735062, 51.124989173311725], [6.814891628658932, 51.125077137378604], [6.818969141037718, 51.127580573411095], [6.823267273017594, 51.129682800956225], [6.827746665230047, 51.13136456924435], [6.832366298448676, 51.13261047778564], [6.832796498448676, 51.13270467778564], [6.834004668609045, 51.13296900254424], [6.834391092882472, 51.1330538927053], [6.83625786469325, 51.133462626617174], [6.836756603365317, 51.13357185038636], [6.837790654730017, 51.133798210586505], [6.837792174775961, 51.13379862016803], [6.837864274775961, 51.13381442016803], [6.838547488231823, 51.13395914662216], [6.838551888231823, 51.13396004662216], [6.84341731290808, 51.13470791331842], [6.848332697330413, 51.13497372877398], [6.853250398325496, 51.13475491652871], [6.858122750266243, 51.13405359745638], [6.858860103708443, 51.133872022904924], [6.859864366429594, 51.13373814429792], [6.864708689444993, 51.13284759423455], [6.869441885681304, 51.131484730234924], [6.874018023170619, 51.12966277782836], [6.878392694077337, 51.1273994176381], [6.882523445641489, 51.12471661380477], [6.886370192149571, 51.12164040084149], [6.888640428417546, 51.11942531484671], [6.889578407491741, 51.11925178383437], [6.889970385604745, 51.11917764740636], [6.890074385604745, 51.11915754740636], [6.890397289162756, 51.119094037040085], [6.891532689162756, 51.11886683704009], [6.892066081996419, 51.11875707775816], [6.89319538199642, 51.11851827775816], [6.893724409638631, 51.118403414964064], [6.894847409638631, 51.11815321496406], [6.895157319183617, 51.118083134026364], [6.895258419183617, 51.11805993402636], [6.895558735245602, 51.11799004331179], [6.896756735245601, 51.11770734331179], [6.897328101803625, 51.11756896314756], [6.898518001803625, 51.11727336314757], [6.8991056261669375, 51.11712359390726], [6.900287226166938, 51.11681479390725], [6.901024648626902, 51.116616046687376], [6.902614348626901, 51.11617454668738], [6.90384624484993

# %%
location_mappings, invalid_h3_cells = get_location_mappings_for_cells(
    list(h3_cells_filtered), nodes, max_tries=20
)
invalid_h3_cells
# Out:
# []

# %%
[lm.osm_node_id for lm in location_mappings if lm.h3_cell == "891fa188c4fffff"]
# Out:
# [2852959462]

# %%
car_location_mappings, invalid_h3_cells = get_location_mappings_for_cells(
    list(h3_cells_filtered), driving_nodes, max_tries=40
)
invalid_h3_cells
# Out:
# []

# %%
storage.write_any_dict(
    {
        "location_mappings": location_mappings,
        "car_location_mappings": car_location_mappings,
    },
    "../data/location_mappings.pkl",
)
