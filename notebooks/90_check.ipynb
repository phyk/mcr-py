# %%
import pyrosm

# %%
reader = pyrosm.OSM("../data/20250214/osm_raw/koeln.osm.pbf")

# %%
network = reader.get_network(nodes=True, network_type="walking")

# %%
nodes, edges = network

# %%
edges
# Out:
#         access  area       bicycle bicycle_road bridge busway cycleway  \
# 0         None  None          None         None   None   None     None
# 1         None  None          None         None   None   None     None
# 2         None  None          None         None   None   None     None
# 3         None  None          None         None   None   None     None
# 4         None  None  use_sidepath         None   None   None     None
# ...        ...   ...           ...          ...    ...    ...      ...
# 1391360   None  None          None         None   None   None     None
# 1391361   None  None          None         None   None   None     None
# 1391362   None  None    designated         None   None   None     None
# 1391363   None  None          None         None   None   None     None
# 1391364   None  None    designated         None   None   None     None
#
#         est_width        foot footway  ... width          id timestamp  \
# ...
